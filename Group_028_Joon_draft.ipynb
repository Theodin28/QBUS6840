# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('UnemploymentRateJan1986-Dec2018.csv')
data.head()
# Out:
#    Months  Unemployment_Rates
# 0  Jan-86                8.53
# 1  Feb-86                8.92
# 2  Mar-86                8.48
# 3  Apr-86                8.06
# 4  May-86                7.71

# %%
data.describe()
# Out:
#        Unemployment_Rates
# count          396.000000
# mean             6.726212
# std              1.811832
# min              3.930000
# 25%              5.410000
# 50%              6.210000
# 75%              7.947500
# max             11.990000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 396 entries, 1986-01-01 to 2018-12-01
# Data columns (total 1 columns):
# Unemployment_Rates    396 non-null float64
# dtypes: float64(1)
# memory usage: 6.2 KB

# %%
data['Months']=pd.to_datetime(data['Months'],format='%b-%y')
data.set_index('Months', inplace=True)
ts = data['Unemployment_Rates']

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
plt.figure()
plt.plot(ts)
plt.title('Unemployment Rates from Jan 1986 to Dec 2018')
plt.xlabel('Time')
plt.ylabel('Unemployment Rates')
# Out:
# Text(0, 0.5, 'Unemployment Rates')

# %%
# Pre-processing
# No missing data --> Normalisation?

# %%
# model selection

# decomposion method --> since the data have been added noises deliberately, this method can show more details after de-trend, de-seasonal and estimae the remainder.
# ARIMA --> advanced model
# Nerual network --> maybe over-complex --> overfitting? (Occam's Razor) But can have a try first to make comparison.
